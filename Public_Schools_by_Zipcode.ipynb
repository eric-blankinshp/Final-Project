# %%
import numpy as np
import pandas as pd

# %%
# Importing csv files and assigning their df. 

school_data = pd.read_csv('Public_Schools_by_Zipcode.csv')  
housing_values = pd.read_csv('Zipcode_HousingValue_Zillow.csv')

# %% [markdown]
# <h1>School Data DF</h1>

# %%
# Checking school DF 
school_data
# Out:
#                    X            Y  OBJECTID        NCESID  \
# 0      -9.844095e+06  5230976.133         1  1.703300e+11
# 1      -9.007027e+06  4195441.532         2  3.702970e+11
# 2      -9.580426e+06  4792069.206         3  1.803690e+11
# 3      -1.243297e+07  3927587.870         4  4.018700e+10
# 4      -1.243258e+07  3924830.599         5  4.018700e+10
# ...              ...          ...       ...           ...
# 101683  1.611973e+07  1514482.859    101684  6.600000e+11
# 101684  1.612110e+07  1521270.610    101685  6.600010e+11
# 101685 -7.453411e+06  2079047.655    101686  7.200030e+11
# 101686 -7.349742e+06  2085641.119    101687  7.200030e+11
# 101687 -7.354107e+06  2033654.514    101688  7.200030e+11
#
#                                                  NAME  \
# 0                            ALDEN-HEBRON HIGH SCHOOL
# 1                              WESTERLY HILLS ACADEMY
# 2                         NORTHWOOD ELEMENTARY SCHOOL
# ...

# %%
#Checking shape of school df. 
school_data.shape
# Out:
# (101688, 33)

# %%
# Checking for null values 

school_data.isnull().sum()
# Out:
# X             0
# Y             0
# OBJECTID      0
# NCESID        0
# NAME          0
# ADDRESS       3
# CITY          0
# STATE         0
# ZIP           0
# ZIP4          0
# TELEPHONE     0
# TYPE          0
# STATUS        0
# POPULATION    0
# COUNTY        0
# COUNTYFIPS    0
# COUNTRY       0
# LATITUDE      0
# LONGITUDE     0
# NAICS_CODE    0
# NAICS_DESC    0
# SOURCE        0
# SOURCEDATE    0
# VAL_METHOD    0
# VAL_DATE      0
# WEBSITE       0
# LEVEL_        0
# ENROLLMENT    0
# ST_GRADE      0
# END_GRADE     0
# DISTRICTID    0
# FT_TEACHER    0
# SHELTER_ID    0
# dtype: int64

# %%
# Dropping null values 

school_data.dropna().shape
# Out:
# (101685, 33)

# %%
# Checking for Unique values in "State" column. We might have international schools in the dataset. 

print(school_data["STATE"].unique())
# Out:
# ['IL' 'NC' 'IN' 'AZ' 'CA' 'DC' 'FL' 'ID' 'KY' 'KS' 'LA' 'MD' 'MI' 'MN'
#  'NH' 'NJ' 'OK' 'TX' 'UT' 'IA' 'OH' 'MS' 'MO' 'SD' 'NM' 'AL' 'PR' 'GU'
#  'AK' 'AR' 'TN' 'WA' 'OR' 'MT' 'ND' 'MA' 'NE' 'WY' 'NV' 'NY' 'PA' 'SC'
#  'WV' 'WI' 'VA' 'CO' 'DE' 'RI' 'GA' 'CT' 'ME' 'VT' 'HI' 'VI' 'AS']

# %%
# Defining list of states 
states = ["PR","GU","HI","VI","AS"]

# %%
# Removing international schools from dataset. PR (Puerto Rico), GU (Guam), HI (Hawaii), VI (Virgin Islands), AS (American Samoa) 

clean_schools_df = school_data[school_data.STATE.isin(states) == False]
clean_schools_df
# Out:
#                    X            Y  OBJECTID        NCESID  \
# 0      -9.844095e+06  5230976.133         1  1.703300e+11
# 1      -9.007027e+06  4195441.532         2  3.702970e+11
# 2      -9.580426e+06  4792069.206         3  1.803690e+11
# 3      -1.243297e+07  3927587.870         4  4.018700e+10
# 4      -1.243258e+07  3924830.599         5  4.018700e+10
# ...              ...          ...       ...           ...
# 101676 -9.820967e+06  5314532.620    101677  5.515780e+11
# 101677 -9.823697e+06  5315933.440    101678  5.515780e+11
# 101678 -9.881268e+06  5646079.505    101679  5.516590e+11
# 101679 -1.218621e+07  5087882.236    101680  5.605760e+11
# 101680 -1.232789e+07  5368482.270    101681  5.605830e+11
#
#                                                  NAME                ADDRESS  \
# 0                            ALDEN-HEBRON HIGH SCHOOL       9604 ILLINOIS ST
# 1                              WESTERLY HILLS ACADEMY        4420 DENVER AVE
# ...

# %%
clean_schools_df.shape
# Out:
# (100447, 33)

# %%
# Checking column names to see which we should keep for future use. 
clean_schools_df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'NCESID', 'NAME', 'ADDRESS', 'CITY', 'STATE',
#        'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'LEVEL_', 'ENROLLMENT', 'ST_GRADE', 'END_GRADE',
#        'DISTRICTID', 'FT_TEACHER', 'SHELTER_ID'],
#       dtype='object')

# %%
# Exporting school csv 

# Create the output file (CSV).
output_data_file = "clean_schools_df"
# Export the City_Data into a CSV.
clean_schools_df.to_csv("cleaned_schools.csv", index=False)

# %% [markdown]
# <h1>Housing Data DF</h1>

# %%
housing_values
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State         City  \
# 0         91940         0       77449        zip        TX    TX          NaN
# 1         91982         1       77494        zip        TX    TX          NaN
# 2         93144         2       79936        zip        TX    TX      El Paso
# 3         62080         3       11368        zip        NY    NY     New York
# 4         62093         4       11385        zip        NY    NY     New York
# ...         ...       ...         ...        ...       ...   ...          ...
# 27398     80190     30657       50160        zip        IA    IA  Martensdale
# 27399     65355     30657       18081        zip        PA    PA   Hellertown
# 27400     80581     30657       51009        zip        IA    IA      Calumet
# 27401     82217     30657       55366        zip        MN    MN          NaN
# 27402     65172     30657       17762        zip        PA    PA  Hughesville
#
# ...

# %%
# Checking Shape

housing_values.shape
# Out:
# (27403, 282)

# %%
# Checking for null values 

housing_values.isnull().sum()
# Out:
# RegionID        0
# SizeRank        0
# RegionName      0
# RegionType      0
# StateName       0
#              ...
# 5/31/2022     201
# 6/30/2022     139
# 7/31/2022      98
# 8/31/2022      59
# 9/30/2022       5
# Length: 282, dtype: int64

# %%
# Dropping null values

cleaned_housing_df = housing_values.dropna()

# %%
# Might have to re-evaluate dropping nas and instead fill them so we keep a majority of our data. 
cleaned_housing_df
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 2         93144         2       79936        zip        TX    TX
# 3         62080         3       11368        zip        NY    NY
# 4         62093         4       11385        zip        NY    NY
# 6         84630         6       60629        zip        IL    IL
# 7         91733         7       77084        zip        TX    TX
# ...         ...       ...         ...        ...       ...   ...
# 27372     90369     30657       74358        zip        OK    OK
# 27373     63527     30657       14441        zip        NY    NY
# 27378     73063     30657       34250        zip        FL    FL
# 27379     72882     30657       33877        zip        FL    FL
# 27380     62607     30657       12489        zip        NY    NY
#
#                City                                  Metro      CountyName  \
# 2           El Paso                            El Paso, TX  El Paso County
# ...

# %%
# Exporting school csv 

# Create the output file (CSV).
output_data_file = "cleaned_housing_df"
# Export the City_Data into a CSV.
cleaned_housing_df.to_csv("cleaned_housing.csv", index=False)
