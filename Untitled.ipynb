# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
merged_df = pd.read_csv('merged_df.csv')
# Out:
# /Users/johannahdelunas/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
merged_df
# Out:
#         RegionID  SizeRank    ZIP RegionType State     City        Metro  \
# 0        93144.0       2.0  79936        zip    TX  El Paso  El Paso, TX
# 1        93144.0       2.0  79936        zip    TX  El Paso  El Paso, TX
# 2        93144.0       2.0  79936        zip    TX  El Paso  El Paso, TX
# 3        93144.0       2.0  79936        zip    TX  El Paso  El Paso, TX
# 4        93144.0       2.0  79936        zip    TX  El Paso  El Paso, TX
# ...          ...       ...    ...        ...   ...      ...          ...
# 101706       NaN       NaN   5661        NaN   NaN      NaN          NaN
# 101707       NaN       NaN   5672        NaN   NaN      NaN          NaN
# 101708       NaN       NaN   5672        NaN   NaN      NaN          NaN
# 101709       NaN       NaN   5343        NaN   NaN      NaN          NaN
# 101710       NaN       NaN   5345        NaN   NaN      NaN          NaN
#
#             CountyName  Housing Value  OBJECTID  ...     VAL_METHOD  \
# 0       El Paso County       196166.0     376.0  ...        IMAGERY
# 1       El Paso County       196166.0   15972.0  ...        IMAGERY
# 2       El Paso County       196166.0   20044.0  ...        IMAGERY
# 3       El Paso County       196166.0   29096.0  ...  IMAGERY/OTHER
# 4       El Paso County       196166.0   29462.0  ...        IMAGERY
# ...                ...            ...       ...  ...            ...
# 101706             NaN            NaN  101519.0  ...  IMAGERY/OTHER
# 101707             NaN            NaN  101517.0  ...  IMAGERY/OTHER
# 101708             NaN            NaN  101518.0  ...  IMAGERY/OTHER
# 101709             NaN            NaN  101520.0  ...  IMAGERY/OTHER
# 101710             NaN            NaN  101522.0  ...  IMAGERY/OTHER
#
#                       VAL_DATE                                       WEBSITE  \
# 0       2018/10/24 00:00:00+00                           http://www.sisd.net
# 1       2010/04/12 00:00:00+00                       http://relwash.yisd.net
# 2       2010/04/06 00:00:00+00                           http://www.sisd.net
# 3       2019/01/14 00:00:00+00                   http://pebblehills.yisd.net
# 4       2010/04/15 00:00:00+00                  http://tierradelsol.yisd.net
# ...                        ...                                           ...
# 101706  2021/05/09 00:00:00+00      http://www.morrisville.org/mes/index.htm
# 101707  2021/05/09 00:00:00+00      http://www.stowe.k12.vt.us/ses/index.htm
# 101708  2021/05/09 00:00:00+00  http://www.stoweschools.com/SSD/SSD_home.htm
# 101709  2021/05/09 00:00:00+00          http://www.jamaicavillageschool.org/
# 101710  2021/05/09 00:00:00+00                 http://www.newbrookschool.org
#
#             LEVEL_ ENROLLMENT ST_GRADE END_GRADE  DISTRICTID  FT_TEACHER  \
# 0       ELEMENTARY      724.0       PK         5   4840710.0        43.0
# 1       ELEMENTARY      603.0       PK         6   4846680.0        39.0
# 2           MIDDLE      988.0        6         8   4840710.0        63.0
# 3       ELEMENTARY      690.0       PK         5   4846680.0        47.0
# 4       ELEMENTARY      698.0       PK         6   4846680.0        45.0
# ...            ...        ...      ...       ...         ...         ...
# 101706  ELEMENTARY      335.0       PK         4   5000448.0        28.0
# 101707  ELEMENTARY      407.0       PK         5   5000448.0        25.0
# 101708        HIGH      426.0        6        12   5000448.0        31.0
# 101709  ELEMENTARY       35.0       PK         5   5000449.0         3.0
# 101710  ELEMENTARY      119.0       PK         5   5000449.0         7.0
#
#            SHELTER_ID
# 0       NOT AVAILABLE
# 1       NOT AVAILABLE
# 2       NOT AVAILABLE
# 3       NOT AVAILABLE
# 4       NOT AVAILABLE
# ...               ...
# 101706  NOT AVAILABLE
# 101707  NOT AVAILABLE
# 101708  NOT AVAILABLE
# 101709  NOT AVAILABLE
# 101710  NOT AVAILABLE
#
# [101711 rows x 39 columns]

# %%
merged_df.dropna()
# Out:
#        RegionID  SizeRank    ZIP RegionType State        City  \
# 0       93144.0       2.0  79936        zip    TX     El Paso
# 1       93144.0       2.0  79936        zip    TX     El Paso
# 2       93144.0       2.0  79936        zip    TX     El Paso
# 3       93144.0       2.0  79936        zip    TX     El Paso
# 4       93144.0       2.0  79936        zip    TX     El Paso
# ...         ...       ...    ...        ...   ...         ...
# 49136   91954.0   30657.0  77464        zip    TX     Orchard
# 49144   67103.0   30657.0  21913        zip    MD  Earleville
# 49146   90262.0   30657.0  74052        zip    OK      Oilton
# 49147   90262.0   30657.0  74052        zip    OK      Oilton
# 49150   77427.0   30657.0  45062        zip    OH  Seven Mile
#
#                                              Metro        CountyName  \
# 0                                      El Paso, TX    El Paso County
# 1                                      El Paso, TX    El Paso County
# 2                                      El Paso, TX    El Paso County
# 3                                      El Paso, TX    El Paso County
# 4                                      El Paso, TX    El Paso County
# ...                                            ...               ...
# 49136         Houston-The Woodlands-Sugar Land, TX  Fort Bend County
# 49144  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD      Cecil County
# 49146                                    Tulsa, OK      Creek County
# 49147                                    Tulsa, OK      Creek County
# 49150                         Cincinnati, OH-KY-IN     Butler County
#
#        Housing Value  OBJECTID  ...     VAL_METHOD                VAL_DATE  \
# 0           196166.0     376.0  ...        IMAGERY  2018/10/24 00:00:00+00
# 1           196166.0   15972.0  ...        IMAGERY  2010/04/12 00:00:00+00
# 2           196166.0   20044.0  ...        IMAGERY  2010/04/06 00:00:00+00
# 3           196166.0   29096.0  ...  IMAGERY/OTHER  2019/01/14 00:00:00+00
# 4           196166.0   29462.0  ...        IMAGERY  2010/04/15 00:00:00+00
# ...              ...       ...  ...            ...                     ...
# 49136       306544.0   72967.0  ...  IMAGERY/OTHER  2016/09/30 00:00:00+00
# 49144       259818.0   60858.0  ...  IMAGERY/OTHER  2010/06/08 00:00:00+00
# 49146        78451.0   30385.0  ...  IMAGERY/OTHER  2019/01/31 00:00:00+00
# 49147        78451.0   43874.0  ...  IMAGERY/OTHER  2010/05/24 00:00:00+00
# 49150       184027.0   59319.0  ...  IMAGERY/OTHER  2016/08/24 00:00:00+00
#
#                               WEBSITE      LEVEL_ ENROLLMENT ST_GRADE  \
# 0                 http://www.sisd.net  ELEMENTARY      724.0       PK
# 1             http://relwash.yisd.net  ELEMENTARY      603.0       PK
# 2                 http://www.sisd.net      MIDDLE      988.0        6
# 3         http://pebblehills.yisd.net  ELEMENTARY      690.0       PK
# 4        http://tierradelsol.yisd.net  ELEMENTARY      698.0       PK
# ...                               ...         ...        ...      ...
# 49136            http://brazosisd.net  ELEMENTARY      336.0       PK
# 49144  http://www.ccps.org/Domain/107  ELEMENTARY      319.0       PK
# 49146         http://oilton.k12.ok.us        HIGH       77.0        9
# 49147         http://oilton.k12.ok.us  ELEMENTARY      176.0       PK
# 49150  http://www.edgewoodschools.com  ELEMENTARY      344.0       KG
#
#       END_GRADE  DISTRICTID  FT_TEACHER     SHELTER_ID
# 0             5   4840710.0        43.0  NOT AVAILABLE
# 1             6   4846680.0        39.0  NOT AVAILABLE
# 2             8   4840710.0        63.0  NOT AVAILABLE
# 3             5   4846680.0        47.0  NOT AVAILABLE
# 4             6   4846680.0        45.0  NOT AVAILABLE
# ...         ...         ...         ...            ...
# 49136         5   4844470.0        23.0  NOT AVAILABLE
# 49144         5   2400240.0        20.0       10811917
# 49146        12   4022560.0         7.0  NOT AVAILABLE
# 49147         8   4022560.0        10.0  NOT AVAILABLE
# 49150         5   3904609.0        18.0  NOT AVAILABLE
#
# [47891 rows x 39 columns]
